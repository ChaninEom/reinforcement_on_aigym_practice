# %%
# !pip3 install box2d-py
# !pip3 install gym[Box_2D]
# Out:
# Collecting box2d-py
#   Downloading box2d_py-2.3.8-cp37-cp37m-manylinux1_x86_64.whl (448 kB)
#      |████████████████████████████████| 448 kB 9.1 MB/s
# Installing collected packages: box2d-py
# Successfully installed box2d-py-2.3.8
# Requirement already satisfied: gym[Box_2D] in /usr/local/lib/python3.7/dist-packages (0.17.3)
# WARNING: gym 0.17.3 does not provide the extra 'box_2d'
# Requirement already satisfied: pyglet<=1.5.0,>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from gym[Box_2D]) (1.5.0)
# Requirement already satisfied: cloudpickle<1.7.0,>=1.2.0 in /usr/local/lib/python3.7/dist-packages (from gym[Box_2D]) (1.3.0)
# Requirement already satisfied: numpy>=1.10.4 in /usr/local/lib/python3.7/dist-packages (from gym[Box_2D]) (1.21.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from gym[Box_2D]) (1.4.1)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from pyglet<=1.5.0,>=1.4.0->gym[Box_2D]) (0.16.0)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import numpy as np
import gym
from tqdm.notebook import tqdm

# %%
class DeepQNetwork(nn.Module):
  def __init__(self, lr, input_dims, fc1_dims, fc2_dims, n_actions):
    super(DeepQNetwork, self).__init__()

    self.input_dims = input_dims
    self.fc1_dims = fc1_dims
    self.fc2_dims = fc2_dims
    self.n_actions = n_actions
    self.fc1 = nn.Linear(*self.input_dims, self.fc1_dims)
    self.fc2 = nn.Linear(self.fc1_dims, self.fc2_dims)
    self.fc3 = nn.Linear(self.fc2_dims, self.n_actions)
    self.optimizer = optim.Adam(self.parameters(), lr = lr)
    self.loss = nn.MSELoss()
    self.device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
    self.to(self.device)
  
  def forward(self, state):
    x = F.relu(self.fc1(state))
    x = F.relu(self.fc2(x))
    actions = self.fc3(x)

    return actions

# %%
class Agent():
  def __init__(self, gamma, epsilon, lr, input_dims, batch_size, n_actions, max_memory_size = 10000, eps_end = 0.01, eps_dec = 5e-4):
    self.gamma = gamma
    self.epsilon = epsilon
    self.eps_min = eps_end
    self.eps_dec = eps_dec
    self.lr = lr

    
    self.action_space = []
    self.action_space = [i for i in range(n_actions)]

    self.mem_size = max_memory_size
    self.batch_size = batch_size
    self.mem_cntr = 0


    self.Q_eval = DeepQNetwork(self.lr, input_dims=input_dims, fc1_dims=256, fc2_dims=256, n_actions=n_actions)

    self.state_memory = np.zeros((self.mem_size, *input_dims), dtype = np.float32)
    self.new_state_memory = np.zeros((self.mem_size, *input_dims), dtype =np.float32)
    self.action_memory = np.zeros(self.mem_size, dtype = np.int32)
    self.reward_memory = np.zeros(self.mem_size, dtype = np.float32)
    self.terminal_memory = np.zeros(self.mem_size, dtype = np.bool)
  
  def store_transition(self, state, action, reward, state_, done):
    index = self.mem_cntr % self.mem_size # memory size 모두 채우면 다시 0번 index로 돌아가서 다시 채움
    self.state_memory[index] = state
    self.new_state_memory[index] = state_
    self.reward_memory[index] = reward
    self.action_memory[index] = action
    self.terminal_memory[index] = done
    self.mem_cntr += 1

  def choose_action(self, observation):
    if np.random.random() > self.epsilon:
        state = torch.tensor([observation]).to(self.Q_eval.device)
        actions = self.Q_eval.forward(state)
        action = torch.argmax(actions).item()
    else:
      action = np.random.choice(self.action_space)
    
    return action
  
  def learn(self):
    if self.mem_cntr < self.batch_size:
      return
    
    self.Q_eval.optimizer.zero_grad()
    max_mem = min(self.mem_cntr, self.mem_size)
    batch = np.random.choice(max_mem, self.batch_size, replace=False)
    batch_index = np.arange(self.batch_size, dtype=np.int32)

    state_batch = torch.tensor(self.state_memory[batch]).to(self.Q_eval.device)
    new_state_batch = torch.tensor(self.new_state_memory[batch]).to(self.Q_eval.device)
    reward_batch = torch.tensor(self.reward_memory[batch]).to(self.Q_eval.device)
    terminal_batch = torch.tensor(self.terminal_memory[batch]).to(self.Q_eval.device)

    action_batch = self.action_memory[batch]

    q_eval = self.Q_eval.forward(state_batch)[batch_index, action_batch]
    q_next = self.Q_eval.forward(new_state_batch)
    q_next[terminal_batch] = 0.0

    q_target = reward_batch + self.gamma *torch.max(q_next, dim=1)[0]

    loss = self.Q_eval.loss(q_target, q_eval).to(self.Q_eval.device)
    loss.backward()
    self.Q_eval.optimizer.step()

    self.epsilon = self.epsilon - self.eps_dec if self.epsilon > self.eps_min else self.eps_min

# %%
env = gym.make('LunarLander-v2')

agent = Agent(gamma=0.99, epsilon=1.0, batch_size=64, n_actions=4, eps_end=0.01, input_dims=[8], lr=0.03)
scores, eps_history = [], []
n_games = 500

for i in range(n_games):
  score = 0
  done = False
  observation = env.reset()
  while not done:
    action = agent.choose_action(observation)
    observation_, reward, done, info = env.step(action)
    score+=reward
    agent.store_transition(observation, action, reward, observation_, done)
    agent.learn()
    observation = observation_
  scores.append(score)
  eps_history.append(agent.epsilon)

  avg_score = np.mean(scores[100:])
  print('epsode :', i, 'score %.2f' %score, 
        'average scroe %.2f' %avg_score,
        'epsilon %.2f' %agent.epsilon )
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:24: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3441: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /usr/local/lib/python3.7/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# epsode : 0 score -147.97 average scroe nan epsilon 1.00
# epsode : 1 score -242.60 average scroe nan epsilon 0.94
# epsode : 2 score -129.72 average scroe nan epsilon 0.89
# epsode : 3 score -125.69 average scroe nan epsilon 0.84
# epsode : 4 score -291.08 average scroe nan epsilon 0.80
# epsode : 5 score -229.53 average scroe nan epsilon 0.73
# epsode : 6 score -181.57 average scroe nan epsilon 0.68
# epsode : 7 score -109.12 average scroe nan epsilon 0.61
# epsode : 8 score -182.50 average scroe nan epsilon 0.57
# epsode : 9 score -134.93 average scroe nan epsilon 0.51
# epsode : 10 score -216.13 average scroe nan epsilon 0.41
# epsode : 11 score -228.03 average scroe nan epsilon 0.30
# epsode : 12 score -274.81 average scroe nan epsilon 0.18
# epsode : 13 score -100.12 average scroe nan epsilon 0.11
# epsode : 14 score -131.87 average scroe nan epsilon 0.03
# epsode : 15 score -73.13 average scroe nan epsilon 0.01
# epsode : 16 score -163.16 average scroe nan epsilon 0.01
# epsode : 17 score -82.63 average scroe nan epsilon 0.01
# epsode : 18 score -259.03 average scroe nan epsilon 0.01
# epsode : 19 score -442.48 average scroe nan epsilon 0.01
# epsode : 20 score -207.39 average scroe nan epsilon 0.01
# epsode : 21 score -78.95 average scroe nan epsilon 0.01
# epsode : 22 score -273.80 average scroe nan epsilon 0.01
# epsode : 23 score -234.01 average scroe nan epsilon 0.01
# epsode : 24 score -167.42 average scroe nan epsilon 0.01
# epsode : 25 score -202.04 average scroe nan epsilon 0.01
# epsode : 26 score 8.16 average scroe nan epsilon 0.01
# epsode : 27 score -66.30 average scroe nan epsilon 0.01
# epsode : 28 score -760.73 average scroe nan epsilon 0.01
# epsode : 29 score -500.48 average scroe nan epsilon 0.01
# epsode : 30 score -59.12 average scroe nan epsilon 0.01
# epsode : 31 score -71.30 average scroe nan epsilon 0.01
# epsode : 32 score 26.69 average scroe nan epsilon 0.01
# epsode : 33 score -223.02 average scroe nan epsilon 0.01
# epsode : 34 score -170.15 average scroe nan epsilon 0.01
# epsode : 35 score -285.90 average scroe nan epsilon 0.01
# epsode : 36 score -149.01 average scroe nan epsilon 0.01
# epsode : 37 score -51.04 average scroe nan epsilon 0.01
# epsode : 38 score -89.33 average scroe nan epsilon 0.01
# epsode : 39 score -182.23 average scroe nan epsilon 0.01
# epsode : 40 score -111.72 average scroe nan epsilon 0.01
# epsode : 41 score -120.60 average scroe nan epsilon 0.01
# epsode : 42 score -63.47 average scroe nan epsilon 0.01
# epsode : 43 score -286.04 average scroe nan epsilon 0.01
# epsode : 44 score -39.20 average scroe nan epsilon 0.01
# epsode : 45 score -145.05 average scroe nan epsilon 0.01
# epsode : 46 score -200.28 average scroe nan epsilon 0.01
# epsode : 47 score -263.00 average scroe nan epsilon 0.01
# epsode : 48 score -90.31 average scroe nan epsilon 0.01
# epsode : 49 score -308.39 average scroe nan epsilon 0.01
# epsode : 50 score -292.42 average scroe nan epsilon 0.01
# epsode : 51 score -191.82 average scroe nan epsilon 0.01
# epsode : 52 score -182.94 average scroe nan epsilon 0.01
# epsode : 53 score -137.78 average scroe nan epsilon 0.01
# epsode : 54 score -128.85 average scroe nan epsilon 0.01
# epsode : 55 score 94.95 average scroe nan epsilon 0.01
# epsode : 56 score -94.60 average scroe nan epsilon 0.01
# epsode : 57 score -71.02 average scroe nan epsilon 0.01
# epsode : 58 score -216.75 average scroe nan epsilon 0.01
# epsode : 59 score -352.61 average scroe nan epsilon 0.01
# epsode : 60 score -57.28 average scroe nan epsilon 0.01
# epsode : 61 score -279.07 average scroe nan epsilon 0.01
# epsode : 62 score -2.81 average scroe nan epsilon 0.01
# epsode : 63 score -135.74 average scroe nan epsilon 0.01
# epsode : 64 score -64.54 average scroe nan epsilon 0.01
# epsode : 65 score -75.56 average scroe nan epsilon 0.01
# epsode : 66 score -151.74 average scroe nan epsilon 0.01
# epsode : 67 score -170.73 average scroe nan epsilon 0.01
# epsode : 68 score -91.06 average scroe nan epsilon 0.01
# epsode : 69 score -214.72 average scroe nan epsilon 0.01
# epsode : 70 score -145.68 average scroe nan epsilon 0.01
# epsode : 71 score -150.58 average scroe nan epsilon 0.01
# epsode : 72 score -176.76 average scroe nan epsilon 0.01
# epsode : 73 score -41.13 average scroe nan epsilon 0.01
# epsode : 74 score -96.61 average scroe nan epsilon 0.01
# epsode : 75 score -32.65 average scroe nan epsilon 0.01
# epsode : 76 score -407.13 average scroe nan epsilon 0.01
# epsode : 77 score -124.59 average scroe nan epsilon 0.01
# epsode : 78 score -55.15 average scroe nan epsilon 0.01
# epsode : 79 score -673.70 average scroe nan epsilon 0.01
# epsode : 80 score -114.59 average scroe nan epsilon 0.01
# epsode : 81 score -487.70 average scroe nan epsilon 0.01
# epsode : 82 score -146.98 average scroe nan epsilon 0.01
# epsode : 83 score -157.93 average scroe nan epsilon 0.01
# epsode : 84 score -149.55 average scroe nan epsilon 0.01
# epsode : 85 score -257.64 average scroe nan epsilon 0.01
# epsode : 86 score -343.90 average scroe nan epsilon 0.01
# epsode : 87 score -55.18 average scroe nan epsilon 0.01
# epsode : 88 score -1.82 average scroe nan epsilon 0.01
# epsode : 89 score -234.97 average scroe nan epsilon 0.01
# epsode : 90 score -111.53 average scroe nan epsilon 0.01
# epsode : 91 score -496.47 average scroe nan epsilon 0.01
# epsode : 92 score -413.89 average scroe nan epsilon 0.01
# epsode : 93 score -470.58 average scroe nan epsilon 0.01
# epsode : 94 score -80.09 average scroe nan epsilon 0.01
# epsode : 95 score -476.14 average scroe nan epsilon 0.01
# epsode : 96 score -455.79 average scroe nan epsilon 0.01
# epsode : 97 score -340.53 average scroe nan epsilon 0.01
# epsode : 98 score -42.88 average scroe nan epsilon 0.01
# epsode : 99 score -103.38 average scroe nan epsilon 0.01
# epsode : 100 score -0.35 average scroe -0.35 epsilon 0.01
# epsode : 101 score -248.52 average scroe -124.44 epsilon 0.01
# epsode : 102 score -148.67 average scroe -132.52 epsilon 0.01
# epsode : 103 score -196.46 average scroe -148.50 epsilon 0.01
# epsode : 104 score -173.07 average scroe -153.42 epsilon 0.01
# epsode : 105 score -9.64 average scroe -129.45 epsilon 0.01
# epsode : 106 score -98.98 average scroe -125.10 epsilon 0.01
# epsode : 107 score -97.18 average scroe -121.61 epsilon 0.01
# epsode : 108 score -178.66 average scroe -127.95 epsilon 0.01
# epsode : 109 score -100.08 average scroe -125.16 epsilon 0.01
# epsode : 110 score -199.72 average scroe -131.94 epsilon 0.01
# epsode : 208 score -40.86 average scroe -156.96 epsilon 0.01
# epsode : 209 score -11.88 average scroe -155.64 epsilon 0.01
# epsode : 210 score 4.25 average scroe -154.20 epsilon 0.01
# epsode : 211 score -80.18 average scroe -153.54 epsilon 0.01
# epsode : 212 score -58.94 average scroe -152.70 epsilon 0.01
# epsode : 213 score -83.38 average scroe -152.09 epsilon 0.01
# epsode : 214 score -17.98 average scroe -150.92 epsilon 0.01
# epsode : 215 score -18.47 average scroe -149.78 epsilon 0.01
# epsode : 216 score -1026.06 average scroe -157.27 epsilon 0.01
# epsode : 217 score -292.94 average scroe -158.42 epsilon 0.01
# epsode : 218 score -303.13 average scroe -159.64 epsilon 0.01
# epsode : 219 score -545.71 average scroe -162.86 epsilon 0.01
# epsode : 220 score -774.89 average scroe -167.91 epsilon 0.01
# epsode : 221 score -465.44 average scroe -170.35 epsilon 0.01
# epsode : 222 score -560.19 average scroe -173.52 epsilon 0.01
# epsode : 223 score -651.94 average scroe -177.38 epsilon 0.01
# epsode : 224 score -280.42 average scroe -178.20 epsilon 0.01
# epsode : 225 score -80.99 average scroe -177.43 epsilon 0.01
# epsode : 226 score -143.31 average scroe -177.16 epsilon 0.01
# epsode : 227 score -205.16 average scroe -177.38 epsilon 0.01
# epsode : 228 score -203.14 average scroe -177.58 epsilon 0.01
# epsode : 229 score -195.18 average scroe -177.72 epsilon 0.01
# epsode : 230 score -60.35 average scroe -176.82 epsilon 0.01
# epsode : 231 score -65.47 average scroe -175.98 epsilon 0.01
# epsode : 232 score 9.39 average scroe -174.58 epsilon 0.01
# epsode : 233 score -597.10 average scroe -177.74 epsilon 0.01
# epsode : 234 score -209.98 average scroe -177.98 epsilon 0.01
# epsode : 235 score -284.31 average scroe -178.76 epsilon 0.01
# epsode : 236 score -170.97 average scroe -178.70 epsilon 0.01
# epsode : 237 score -65.21 average scroe -177.88 epsilon 0.01
# epsode : 238 score -129.55 average scroe -177.53 epsilon 0.01
# epsode : 239 score -351.96 average scroe -178.78 epsilon 0.01
# epsode : 240 score -572.41 average scroe -181.57 epsilon 0.01
# epsode : 241 score -524.53 average scroe -183.98 epsilon 0.01
# epsode : 242 score -554.20 average scroe -186.57 epsilon 0.01
# epsode : 243 score -43.17 average scroe -185.58 epsilon 0.01
# epsode : 244 score -95.47 average scroe -184.96 epsilon 0.01
# epsode : 245 score -70.79 average scroe -184.17 epsilon 0.01
# epsode : 246 score -130.93 average scroe -183.81 epsilon 0.01
# epsode : 247 score -184.10 average scroe -183.81 epsilon 0.01
# epsode : 248 score -67.54 average scroe -183.03 epsilon 0.01
# epsode : 249 score -114.84 average scroe -182.58 epsilon 0.01
# epsode : 250 score -15.03 average scroe -181.47 epsilon 0.01
# epsode : 251 score -107.42 average scroe -180.98 epsilon 0.01
# epsode : 252 score -3.03 average scroe -179.82 epsilon 0.01
# epsode : 253 score -22.26 average scroe -178.80 epsilon 0.01
# epsode : 254 score -53.03 average scroe -177.98 epsilon 0.01
# epsode : 255 score -98.84 average scroe -177.48 epsilon 0.01
# epsode : 256 score -215.75 average scroe -177.72 epsilon 0.01
# epsode : 257 score -93.85 average scroe -177.19 epsilon 0.01
# epsode : 258 score -89.09 average scroe -176.64 epsilon 0.01
# epsode : 259 score -37.48 average scroe -175.77 epsilon 0.01
# epsode : 260 score -142.15 average scroe -175.56 epsilon 0.01
# epsode : 261 score -266.46 average scroe -176.12 epsilon 0.01
# epsode : 262 score -34.20 average scroe -175.25 epsilon 0.01
# epsode : 263 score -329.45 average scroe -176.19 epsilon 0.01
# epsode : 264 score -121.76 average scroe -175.86 epsilon 0.01
# epsode : 265 score -82.24 average scroe -175.29 epsilon 0.01
# epsode : 266 score -33.85 average scroe -174.45 epsilon 0.01
# epsode : 267 score -101.75 average scroe -174.01 epsilon 0.01
# epsode : 268 score -126.46 average scroe -173.73 epsilon 0.01
# epsode : 269 score -115.81 average scroe -173.39 epsilon 0.01
# epsode : 270 score -588.87 average scroe -175.82 epsilon 0.01
# epsode : 271 score -281.18 average scroe -176.43 epsilon 0.01
# epsode : 272 score -103.24 average scroe -176.01 epsilon 0.01
# epsode : 273 score 11.02 average scroe -174.94 epsilon 0.01
# epsode : 274 score -95.24 average scroe -174.48 epsilon 0.01
# epsode : 275 score -44.79 average scroe -173.74 epsilon 0.01
# epsode : 276 score -38.04 average scroe -172.98 epsilon 0.01
# epsode : 277 score -70.09 average scroe -172.40 epsilon 0.01
# epsode : 278 score -85.67 average scroe -171.92 epsilon 0.01
# epsode : 279 score -811.94 average scroe -175.47 epsilon 0.01
# epsode : 280 score -771.64 average scroe -178.76 epsilon 0.01
# epsode : 281 score -605.20 average scroe -181.11 epsilon 0.01
# epsode : 282 score -218.25 average scroe -181.31 epsilon 0.01
# epsode : 283 score -419.46 average scroe -182.60 epsilon 0.01
# epsode : 284 score -407.04 average scroe -183.82 epsilon 0.01
# epsode : 285 score -151.89 average scroe -183.65 epsilon 0.01
# epsode : 286 score -662.14 average scroe -186.21 epsilon 0.01
# epsode : 287 score -598.73 average scroe -188.40 epsilon 0.01
# epsode : 288 score -427.46 average scroe -189.66 epsilon 0.01
# epsode : 289 score -600.81 average scroe -191.83 epsilon 0.01
# epsode : 290 score -338.37 average scroe -192.60 epsilon 0.01
# epsode : 291 score -82.20 average scroe -192.02 epsilon 0.01
# epsode : 292 score -597.80 average scroe -194.12 epsilon 0.01
# epsode : 293 score -382.20 average scroe -195.09 epsilon 0.01
# epsode : 294 score -18.85 average scroe -194.19 epsilon 0.01
# epsode : 295 score -258.63 average scroe -194.52 epsilon 0.01
# epsode : 296 score -511.93 average scroe -196.13 epsilon 0.01
# epsode : 297 score -303.11 average scroe -196.67 epsilon 0.01
# epsode : 298 score -323.19 average scroe -197.30 epsilon 0.01
# epsode : 299 score -959.80 average scroe -201.12 epsilon 0.01
# epsode : 300 score -510.50 average scroe -202.66 epsilon 0.01
# epsode : 301 score -86.19 average scroe -202.08 epsilon 0.01
# epsode : 302 score -767.08 average scroe -204.86 epsilon 0.01
# epsode : 303 score -759.96 average scroe -207.58 epsilon 0.01
# epsode : 304 score -219.90 average scroe -207.64 epsilon 0.01
# epsode : 305 score -155.87 average scroe -207.39 epsilon 0.01
# epsode : 354 score -333.73 average scroe -210.87 epsilon 0.01
# epsode : 355 score -164.86 average scroe -210.69 epsilon 0.01
# epsode : 356 score -143.27 average scroe -210.43 epsilon 0.01
# epsode : 357 score -61.31 average scroe -209.85 epsilon 0.01
# epsode : 358 score -109.42 average scroe -209.47 epsilon 0.01
# epsode : 359 score -210.54 average scroe -209.47 epsilon 0.01
# epsode : 360 score -27.36 average scroe -208.77 epsilon 0.01
# epsode : 361 score -222.55 average scroe -208.82 epsilon 0.01
# epsode : 362 score -123.72 average scroe -208.50 epsilon 0.01
# epsode : 363 score -157.88 average scroe -208.31 epsilon 0.01
# epsode : 364 score -225.86 average scroe -208.38 epsilon 0.01
# epsode : 365 score -63.13 average scroe -207.83 epsilon 0.01
# epsode : 366 score -179.69 average scroe -207.72 epsilon 0.01
# epsode : 367 score -182.30 average scroe -207.63 epsilon 0.01
# epsode : 368 score -111.72 average scroe -207.27 epsilon 0.01
# epsode : 369 score -118.78 average scroe -206.94 epsilon 0.01
# epsode : 370 score -200.53 average scroe -206.92 epsilon 0.01
# epsode : 371 score -61.69 average scroe -206.39 epsilon 0.01
# epsode : 372 score -157.64 average scroe -206.21 epsilon 0.01
# epsode : 373 score -281.67 average scroe -206.48 epsilon 0.01
# epsode : 374 score -98.25 average scroe -206.09 epsilon 0.01
# epsode : 375 score -48.61 average scroe -205.52 epsilon 0.01
# epsode : 376 score 8.13 average scroe -204.75 epsilon 0.01
# epsode : 377 score -111.98 average scroe -204.41 epsilon 0.01
# epsode : 378 score -299.09 average scroe -204.75 epsilon 0.01
# epsode : 379 score -57.25 average scroe -204.23 epsilon 0.01
# epsode : 380 score -222.16 average scroe -204.29 epsilon 0.01
# epsode : 381 score -53.31 average scroe -203.76 epsilon 0.01
# epsode : 382 score -215.18 average scroe -203.80 epsilon 0.01
# epsode : 383 score -245.43 average scroe -203.94 epsilon 0.01
# epsode : 384 score -260.51 average scroe -204.14 epsilon 0.01
# epsode : 385 score -99.91 average scroe -203.78 epsilon 0.01
# epsode : 386 score -92.95 average scroe -203.39 epsilon 0.01
# epsode : 387 score -91.72 average scroe -203.00 epsilon 0.01
# epsode : 388 score -285.63 average scroe -203.29 epsilon 0.01
# epsode : 389 score -102.67 average scroe -202.94 epsilon 0.01
# epsode : 390 score -567.46 average scroe -204.19 epsilon 0.01
# epsode : 391 score -306.27 average scroe -204.54 epsilon 0.01
# epsode : 392 score -213.99 average scroe -204.58 epsilon 0.01
# epsode : 393 score -632.31 average scroe -206.03 epsilon 0.01
# epsode : 394 score -519.11 average scroe -207.09 epsilon 0.01
# epsode : 395 score -240.23 average scroe -207.20 epsilon 0.01
# epsode : 396 score -233.40 average scroe -207.29 epsilon 0.01
# epsode : 397 score -295.18 average scroe -207.59 epsilon 0.01
# epsode : 398 score -423.99 average scroe -208.31 epsilon 0.01
# epsode : 399 score -754.86 average scroe -210.13 epsilon 0.01
# epsode : 400 score -207.61 average scroe -210.12 epsilon 0.01
# epsode : 401 score -280.70 average scroe -210.36 epsilon 0.01
# epsode : 402 score -242.85 average scroe -210.47 epsilon 0.01
# epsode : 403 score 8.78 average scroe -209.74 epsilon 0.01
# epsode : 404 score -72.16 average scroe -209.29 epsilon 0.01
# epsode : 405 score -123.58 average scroe -209.01 epsilon 0.01
# epsode : 406 score -112.83 average scroe -208.70 epsilon 0.01
# epsode : 407 score -212.64 average scroe -208.71 epsilon 0.01
# epsode : 408 score -215.27 average scroe -208.73 epsilon 0.01
# epsode : 409 score -174.68 average scroe -208.62 epsilon 0.01
# epsode : 410 score -125.83 average scroe -208.36 epsilon 0.01
# epsode : 411 score -119.14 average scroe -208.07 epsilon 0.01
# epsode : 412 score -494.74 average scroe -208.99 epsilon 0.01
# epsode : 413 score -531.97 average scroe -210.02 epsilon 0.01
# epsode : 414 score -411.32 average scroe -210.66 epsilon 0.01
# epsode : 415 score -587.82 average scroe -211.85 epsilon 0.01
# epsode : 416 score -51.71 average scroe -211.34 epsilon 0.01
# epsode : 417 score -235.58 average scroe -211.42 epsilon 0.01
# epsode : 418 score -29.10 average scroe -210.85 epsilon 0.01
# epsode : 419 score -4.34 average scroe -210.20 epsilon 0.01
# epsode : 420 score -44.81 average scroe -209.69 epsilon 0.01
# epsode : 421 score -181.45 average scroe -209.60 epsilon 0.01
# epsode : 422 score -609.44 average scroe -210.84 epsilon 0.01
# epsode : 423 score -119.42 average scroe -210.56 epsilon 0.01
# epsode : 424 score -81.70 average scroe -210.16 epsilon 0.01
# epsode : 425 score -98.55 average scroe -209.82 epsilon 0.01
# epsode : 426 score -469.94 average scroe -210.61 epsilon 0.01
# epsode : 427 score -104.50 average scroe -210.29 epsilon 0.01
# epsode : 428 score -85.00 average scroe -209.91 epsilon 0.01
# epsode : 429 score -87.09 average scroe -209.54 epsilon 0.01
# epsode : 430 score -85.29 average scroe -209.16 epsilon 0.01
# epsode : 431 score -88.65 average scroe -208.80 epsilon 0.01
# epsode : 432 score -89.91 average scroe -208.44 epsilon 0.01
# epsode : 433 score -37.01 average scroe -207.93 epsilon 0.01
# epsode : 434 score -12.48 average scroe -207.34 epsilon 0.01
# epsode : 435 score -29.43 average scroe -206.81 epsilon 0.01
# epsode : 436 score 26.47 average scroe -206.12 epsilon 0.01
# epsode : 437 score -42.20 average scroe -205.64 epsilon 0.01
# epsode : 438 score -925.19 average scroe -207.76 epsilon 0.01
# epsode : 439 score -393.07 average scroe -208.31 epsilon 0.01
# epsode : 440 score -715.88 average scroe -209.79 epsilon 0.01
# epsode : 441 score -127.24 average scroe -209.55 epsilon 0.01
# epsode : 442 score -60.40 average scroe -209.12 epsilon 0.01
# epsode : 443 score -129.69 average scroe -208.89 epsilon 0.01
# epsode : 444 score -109.31 average scroe -208.60 epsilon 0.01
# epsode : 445 score -82.46 average scroe -208.23 epsilon 0.01
# epsode : 446 score -44.65 average scroe -207.76 epsilon 0.01
# epsode : 447 score -141.21 average scroe -207.57 epsilon 0.01
# epsode : 448 score -106.69 average scroe -207.28 epsilon 0.01
# epsode : 449 score -23.94 average scroe -206.76 epsilon 0.01
# epsode : 450 score -144.59 average scroe -206.58 epsilon 0.01
# epsode : 451 score -136.20 average scroe -206.38 epsilon 0.01
# epsode : 452 score -164.95 average scroe -206.26 epsilon 0.01
# epsode : 453 score -107.31 average scroe -205.98 epsilon 0.01
# epsode : 454 score -97.65 average scroe -205.68 epsilon 0.01
# epsode : 455 score -153.74 average scroe -205.53 epsilon 0.01
# epsode : 456 score -153.60 average scroe -205.39 epsilon 0.01
# epsode : 457 score -145.73 average scroe -205.22 epsilon 0.01
# epsode : 458 score -119.45 average scroe -204.98 epsilon 0.01
# epsode : 459 score -131.70 average scroe -204.78 epsilon 0.01
# epsode : 460 score -166.55 average scroe -204.67 epsilon 0.01
# epsode : 461 score -123.04 average scroe -204.45 epsilon 0.01
# epsode : 462 score -129.01 average scroe -204.24 epsilon 0.01
# epsode : 463 score -127.24 average scroe -204.03 epsilon 0.01
# epsode : 464 score -148.70 average scroe -203.88 epsilon 0.01
# epsode : 465 score -158.22 average scroe -203.75 epsilon 0.01
# epsode : 466 score -112.25 average scroe -203.50 epsilon 0.01
# epsode : 467 score -162.31 average scroe -203.39 epsilon 0.01
# epsode : 468 score -176.34 average scroe -203.32 epsilon 0.01
# epsode : 469 score -145.08 average scroe -203.16 epsilon 0.01
# epsode : 470 score -129.30 average scroe -202.96 epsilon 0.01
# epsode : 471 score -149.24 average scroe -202.82 epsilon 0.01
# epsode : 472 score -99.81 average scroe -202.54 epsilon 0.01
# epsode : 473 score -110.95 average scroe -202.29 epsilon 0.01
# epsode : 474 score -141.30 average scroe -202.13 epsilon 0.01
# epsode : 475 score -78.84 average scroe -201.80 epsilon 0.01
# epsode : 476 score -92.80 average scroe -201.51 epsilon 0.01
# epsode : 477 score -122.43 average scroe -201.31 epsilon 0.01
# epsode : 478 score -230.77 average scroe -201.38 epsilon 0.01
# epsode : 479 score -84.82 average scroe -201.08 epsilon 0.01
# epsode : 480 score -402.77 average scroe -201.61 epsilon 0.01
# epsode : 481 score -321.18 average scroe -201.92 epsilon 0.01
# epsode : 482 score -59.00 average scroe -201.55 epsilon 0.01
# epsode : 483 score -206.52 average scroe -201.56 epsilon 0.01
# epsode : 484 score -242.95 average scroe -201.67 epsilon 0.01
# epsode : 485 score -340.28 average scroe -202.03 epsilon 0.01
# epsode : 486 score -155.00 average scroe -201.90 epsilon 0.01
# epsode : 487 score -126.62 average scroe -201.71 epsilon 0.01
# epsode : 488 score -103.48 average scroe -201.46 epsilon 0.01
# epsode : 489 score -88.28 average scroe -201.17 epsilon 0.01
# epsode : 490 score -136.44 average scroe -201.00 epsilon 0.01
# epsode : 491 score -138.97 average scroe -200.84 epsilon 0.01
# epsode : 492 score -132.07 average scroe -200.67 epsilon 0.01
# epsode : 493 score -153.61 average scroe -200.55 epsilon 0.01
# epsode : 494 score -151.14 average scroe -200.42 epsilon 0.01
# epsode : 495 score -136.55 average scroe -200.26 epsilon 0.01
# epsode : 496 score -129.04 average scroe -200.08 epsilon 0.01
# epsode : 497 score -65.18 average scroe -199.74 epsilon 0.01
# epsode : 498 score -47.07 average scroe -199.36 epsilon 0.01
# epsode : 499 score -263.39 average scroe -199.52 epsilon 0.01
